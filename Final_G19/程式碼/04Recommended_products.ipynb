# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series
import datetime

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics: 
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
from datetime import datetime
def datelist(beginDate, endDate):
    # beginDate, endDate是形如‘20160601’的字符串或datetime格式
    date_l=[datetime.strftime(x,'%Y-%m-%d') for x in list(pd.date_range(start=beginDate, end=endDate))]
    return date_l

# %%
# %%time
M_data = pd.DataFrame(pd.read_csv("data/MemberData.csv",low_memory=False))
O_data = pd.DataFrame(pd.read_csv("data/OrderData.csv",low_memory=False))
OS_data = pd.DataFrame(pd.read_csv("data/OrderSlaveData.csv",low_memory=False))
M_data['RegisterDateTime'] = pd.to_datetime(M_data['RegisterDateTime'].astype(str).str[0:10], format = "%Y-%m-%d") 
OS_data['TradesDateTime'] = pd.to_datetime(OS_data['TradesDateTime'].astype(str).str[0:10], format = "%Y-%m-%d") 
O_data['TradesDateTime'] = pd.to_datetime(O_data['TradesDateTime'].astype(str).str[0:10], format = "%Y-%m-%d")
# Out:
# Wall time: 6.08 s

# %%
print("MemberData資料筆數：",M_data.shape)
print("OrderData資料筆數：",O_data.shape)
print("OrderSlaveData資料筆數：",OS_data.shape)
# Out:
# MemberData資料筆數： (337576, 11)
# OrderData資料筆數： (502402, 16)
# OrderSlaveData資料筆數： (841332, 15)

# %%
M_data['RegisterDateTime'] = pd.to_datetime(M_data['RegisterDateTime'].astype(str).str[0:10], format = "%Y-%m-%d") 
OS_data['TradesDateTime'] = pd.to_datetime(OS_data['TradesDateTime'].astype(str).str[0:10], format = "%Y-%m-%d") 
O_data['TradesDateTime'] = pd.to_datetime(O_data['TradesDateTime'].astype(str).str[0:10], format = "%Y-%m-%d")

# %%
M_data.head()
# Out:
#   RegisterSourceTypeDef RegisterDateTime  Gender    Birthday  IsAppInstalled  \
# 0                iOSApp       2014-12-27  Female  1983-10-19            True
# 1                   NaN       2015-05-29  Female  1990-03-13            True
# 2                   NaN       2013-10-23     NaN  1900-01-01            True
# 3                   NaN       2015-06-27  Female  1977-03-14            True
# 4                   NaN       2015-06-03  Female  1983-01-15            True
#
#    IsEnableEmail  IsEnablePushNotification  IsEnableShortMessage  \
# 0           True                      True                  True
# 1           True                      True                  True
# 2           True                      True                  True
# 3           True                      True                  True
# 4           True                      True                  True
#
#    MemberCardLevel                                           MemberID  \
# 0               10  b%2Be6RCNYUwTRO%2BnSBeE4H7ySets9zgOaGkqDYItQZS...
# 1               10  %2FL156mdTEuzDIF5ulSFL4mhJdNRGs8haMhCgz%2BSrG9...
# 2               10   wj5w28khA7PlMGGXYaUHIfTxKhjae8pnB76k46OL%2Bhc%3D
# 3               10     rvJ4K4pF5BYUVUVZnRdcsc0AMlVLX0T2warN0CyPKmU%3D
# 4               10  Oalq5zcQazy%2B%2BnozogEXMbTItDObkJMUPzz4H%2Fn7...
#
#   eland_uuid
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
O_data.head()
# Out:
#   TradesGroupCode TradesDateTime   ChannelType ChannelDetail PaymentType  \
# 0  TG190926B00185     2019-09-26  OfficialECom     MobileWeb      JKOPay
# 1  TG190926X00450     2019-09-26  OfficialECom        iOSApp      JKOPay
# 2  TG190928M00620     2019-09-28  OfficialECom     MobileWeb      JKOPay
# 3  TG190928U00383     2019-09-28  OfficialECom        iOSApp      JKOPay
# 4  TG190929R00721     2019-09-29  OfficialECom     MobileWeb      JKOPay
#
#    ShippingType  TsCount  Qty  TotalSalesAmount  TotalPrice  TotalDiscount  \
# 0          Home        1    1               680         680              0
# 1  FamilyPickup        4    4              2660        2760           -100
# 2  FamilyPickup        1    1              1016        1280           -264
# 3  FamilyPickup        1    1              1380        1480           -100
# 4  FamilyPickup        1    1              1780        1880           -100
#
#    TotalPromotionDiscount  TotalCouponDiscount  TotalLoyaltyDiscount  Status  \
# 0                       0                    0                     0  Finish
# 1                       0                 -100                     0  Finish
# 2                     -64                 -200                     0  Finish
# 3                       0                 -100                     0  Finish
# 4                       0                 -100                     0  Cancel
#
#                                            MemberID
# 0  JAE7ypAI%2BmBkMAd1REpPJI3zcEQBI9WBTeg5QlsEri4%3D
# 1  UB%2F0WwXAdW5GhwWmVB036mhSMcUnbK1IA5kXp31h4XQ%3D
# 2    rKUVLmkXyUqqVN8zU1UB40kuhBLRok8FvQtDZTGIS00%3D
# 3  WpUUri%2BOuznMIisbG5ramILffQkqoQr8TPOj0L8lqN8%3D
# 4  acrdzjptXw%2FDeckXY4b5R89lYb41BC0H0bEgiTo9Zj8%3D

# %%
OS_data.head()
# Out:
#   TradesGroupCode TradesDateTime   ChannelType ChannelDetail PaymentType  \
# 0  TG190925A00551     2019-09-25  OfficialECom     MobileWeb      JKOPay
# 1  TG190925A00551     2019-09-25  OfficialECom     MobileWeb      JKOPay
# 2  TG190926X00450     2019-09-26  OfficialECom        iOSApp      JKOPay
# 3  TG190926X00450     2019-09-26  OfficialECom        iOSApp      JKOPay
# 4  TG190928U00383     2019-09-28  OfficialECom        iOSApp      JKOPay
#
#    ShippingType OuterProductSkuCode  ProductSkuCode  SalePageCode  Qty  \
# 0          Home          9021-1BE35      15016264.0     5074360.0    1
# 1          Home          6182-1DB35      16417049.0     5515813.0    1
# 2  FamilyPickup          8309-3WH34      11397813.0     3904262.0    1
# 3  FamilyPickup               SSS84      16578545.0     5575777.0    1
# 4  FamilyPickup           002-3WH40       8771599.0     3136651.0    1
#
#    TotalSalesAmount  TotalPrice  TotalDiscount  Status  \
# 0              4040        4140           -100  Cancel
# 1              4040        4140           -100  Cancel
# 2              2660        2760           -100  Finish
# 3              2660        2760           -100  Finish
# 4              1380        1480           -100  Finish
#
#                                             MemberID
# 0  tZku5%2Bsy%2F4HUcFAJTcgByc5UWKnrXkyL7ikewfJwoE...
# 1  tZku5%2Bsy%2F4HUcFAJTcgByc5UWKnrXkyL7ikewfJwoE...
# 2   UB%2F0WwXAdW5GhwWmVB036mhSMcUnbK1IA5kXp31h4XQ%3D
# 3   UB%2F0WwXAdW5GhwWmVB036mhSMcUnbK1IA5kXp31h4XQ%3D
# 4   WpUUri%2BOuznMIisbG5ramILffQkqoQr8TPOj0L8lqN8%3D

# %%
list_ = datelist('20180627','20200430')
print("共計總天數",len(list_)+1)
# Out:
# 共計總天數 675

# %%
M_data['MemberID'].value_counts()
# 代表有會員id是重複的
# Out:
# jxYhHrEqmnI43qyBLvKlZQ%3D%3D                        16197
# vCVjyMZUAth%2BoZkI3ov4kC6HErGEE7HdBFQgmZbTIkA%3D       74
# sc1vUHKOmjfRYu7qt8hrWfFBIBPgYkQzs%2B5spbRpons%3D       66
# qlSH7MDmiJYVKo8z7MxNaRVjgWId5R3tTFqzARGr4RQ%3D         51
# GVtcqdyZ0BpNrwir6S6JtflRovLyJkMNkjqr92i9xrM%3D         49
#                                                     ...
# pv6uFZCd9gZo51FCL7S4XJZ7EJjSmQMdIKFPAmZ1Oak%3D          1
# r0w%2FrX2op2j0RV0b4ZH6nEBhz09Ph1jl3jZc6CJXjtw%3D        1
# efl9HCNDGT1SipSlM18%2BjxalfdvUsU0lVeSAOHNuS9c%3D        1
# 16LbfPHuA94CZJi%2Ba0pNvLgEjkCSsZPtbzNgujhGJeY%3D        1
# NjcJkTNEh2iC1JpioO%2Bvkbbh8ZaR4YZU5XwVLVwG1lk%3D        1
# Name: MemberID, Length: 313668, dtype: int64

# %%
# %%time
df = pd.DataFrame(pd.read_csv("data/Behavior/123_new/productPageView_2018-06-26.csv",low_memory=False))
df = pd.DataFrame(df, columns = ['uid','ht','pr1id'] )
for i in range(len(list_)):
    path = 'data/Behavior/123_new/productPageView_' + list_[i] + '.csv'
    df1 = pd.read_csv(path, low_memory=False)
    df1 = pd.DataFrame(df1, columns = ['uid','ht','pr1id'] )
    df = pd.concat([df, df1], axis = 0)
# print(df.shape)
# Out:
# Wall time: 1min 44s

# %%
df
# Out:
#                                                     uid             ht  \
# 0                                                   NaN  1529984856928
# 1                                                   NaN  1530052755380
# 2                                                   NaN  1530007429153
# 3                                                   NaN  1530005672236
# 4                                                   NaN  1530007683619
# ...                                                 ...            ...
# 14900  4oXbuD0UAWgi8f2o%2FzFUxDvsGDgla9VkiFdyx4f9SXY%3D  1588250697451
# 14901    0joCRJv2K5ypbluZEmEDyrC5wZuJ5bZ4L7tGbATY2ms%3D  1588223230535
# 14902    0joCRJv2K5ypbluZEmEDyrC5wZuJ5bZ4L7tGbATY2ms%3D  1588223394110
# 14903    0joCRJv2K5ypbluZEmEDyrC5wZuJ5bZ4L7tGbATY2ms%3D  1588207798103
# 14904  HPpytlrp602hxpvIGDFDNDSnNHX%2FMZL5yFHOWThUOrc%3D  1588251528451
#
#          pr1id
# 0        41490
# 1        41490
# 2        41490
# 3      3960793
# 4      3960793
# ...        ...
# 14900  5898619
# 14901  5993550
# 14902  5993550
# 14903  5288532
# 14904  6312881
#
# [12019168 rows x 3 columns]

# %%
import datetime
df.loc[:,'ht'] = [datetime.datetime.fromtimestamp(i/1000).strftime("%Y-%m-%d") for i in df['ht']]
df['ht'] = pd.to_datetime(df['ht'].astype(str).str[0:10], format = "%Y-%m-%d")
print(df.shape)
# Out:
# (12019168, 3)

# %%
df = df.dropna()
print(df.shape)
# Out:
# (5644067, 3)

# %%
df.to_csv('View_Page.csv', index = False)

# %%
View = pd.read_csv('View_Page.csv',low_memory=False)
View = reduce_mem_usage(View)
View = pd.DataFrame(View, columns = ['uid','ht','pr1id'] )
View.head()
# Out:
# Mem. usage decreased to 107.65 Mb (16.7% reduction)
#                                               uid          ht    pr1id
# 0  YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26  4440043
# 1  YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26  4450808
# 2  YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26  4508572
# 3  YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26  3533076
# 4  YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26  4456042

# %%
print("商品數",len(View['pr1id'].unique())) # 商品數
print(View.shape)
# Out:
# 商品數 3878
# (5644067, 3)

# %%
# %%time
from datetime import datetime
list_ = datelist('20180626','20190101')
print("day", len(list_))
sub = View[View['ht']<list_[-1]]
sub.head()
print(sub.shape)
sub = sub.drop_duplicates(subset=None, keep='first', inplace=False)
print(sub.shape)
# Out:
# day 190
# (1202531, 3)
# (945684, 3)
# Wall time: 1.71 s

# %%
sub
# Out:
#                                                        uid          ht  \
# 0           YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26
# 1           YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26
# 2           YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26
# 3           YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26
# 4           YP4rsCTcLZMhO8CXsQDoB5KonLHEM6km1ycEBT9Hxtw%3D  2018-06-26
# ...                                                    ...         ...
# 1203337   Uaf5V%2B8kLv73Yhc2L1Jq8eG8gPhx8yYiNCUVifDXNZw%3D  2018-12-31
# 1203339   Uaf5V%2B8kLv73Yhc2L1Jq8eG8gPhx8yYiNCUVifDXNZw%3D  2018-12-31
# 1203340   Uaf5V%2B8kLv73Yhc2L1Jq8eG8gPhx8yYiNCUVifDXNZw%3D  2018-12-31
# 1203341   Uaf5V%2B8kLv73Yhc2L1Jq8eG8gPhx8yYiNCUVifDXNZw%3D  2018-12-31
# 1203342  AGcdW8%2B2yO5sUnJl3RVnXfxpTsWhKyb%2F1zzNNSjxYq...  2018-12-31
#
#            pr1id
# 0        4440043
# 1        4450808
# 2        4508572
# 3        3533076
# 4        4456042
# ...          ...
# 1203337  4841961
# 1203339  4841963
# 1203340  4841955
# 1203341  4780430
# 1203342  4808555
#
# [945684 rows x 3 columns]

# %%
list_1 = datelist('20190101','20190630')

# %%
# %%time
view_matrix = pd.pivot_table(sub, index="uid", columns="pr1id", aggfunc='count')
view_matrix.fillna(value=0, inplace=True)
view_matrix
# Out:
# Wall time: 11.6 s
#                                                         ht                  \
# pr1id                                              41488   41490   41560
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
#                                                                             \
# pr1id                                              41562   153024  153049
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     1.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
#                                                                             \
# pr1id                                              153055  154238  154247
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     1.0     0.0
#
#                                                             ...          \
# pr1id                                              154251   ... 5073721
# uid                                                         ...
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0  ...     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0  ...     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0  ...     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0  ...     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0  ...     0.0
# ...                                                    ...  ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0  ...     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0  ...     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0  ...     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0  ...     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0  ...     0.0
#
#                                                                             \
# pr1id                                              5073726 5074265 5074360
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
#                                                                             \
# pr1id                                              5074457 5074545 5074580
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
#
# pr1id                                              5074637 5074706 5074753
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
# [59472 rows x 1672 columns]

# %%
# view_matrix = reduce_mem_usage(view_matrix)

# %%
view_matrix
# Out:
#                                                         ht                  \
# pr1id                                              41488   41490   41560
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
#                                                                             \
# pr1id                                              41562   153024  153049
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     1.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
#                                                                             \
# pr1id                                              153055  154238  154247
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     1.0     0.0
#
#                                                             ...          \
# pr1id                                              154251   ... 5073721
# uid                                                         ...
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0  ...     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0  ...     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0  ...     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0  ...     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0  ...     0.0
# ...                                                    ...  ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0  ...     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0  ...     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0  ...     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0  ...     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0  ...     0.0
#
#                                                                             \
# pr1id                                              5073726 5074265 5074360
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
#                                                                             \
# pr1id                                              5074457 5074545 5074580
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
#
# pr1id                                              5074637 5074706 5074753
# uid
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...     0.0     0.0     0.0
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...     0.0     0.0     0.0
# %2B%2BB3LdtIYEk9XGz9jG%2F5n7C740nRzI02Ig7uHKfNT...     0.0     0.0     0.0
# %2B%2BH2qr3ZTZV%2BEFF8cHKhtWa4KvG4hiPRX%2BsYTjD...     0.0     0.0     0.0
# %2B%2BKWWfO7UJQhmQXfJHoERSh2Ha4XnWrMJRMdMhB3xIw%3D     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zzozEazXjgKfDpsvvu4jW%2BuYT9vowDYVnYBKrsyO0uo%3D       0.0     0.0     0.0
# zzpr4DLdeOxM9QJ9%2BC56UADVWTZ0IFwoZUwSrQngg1o%3D       0.0     0.0     0.0
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D       0.0     0.0     0.0
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D     0.0     0.0     0.0
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D         0.0     0.0     0.0
#
# [59472 rows x 1672 columns]

# %%
index = view_matrix.columns
view_matrix.columns = [i[1] for i in index]
# view_matrix.columns

# %%
# %%time

for i in list(view_matrix.columns[:50]):
    target_item = view_matrix[i]

    similarity_with_other_items = view_matrix.corrwith(target_item)  # find correlation between "Bad Boys (1995)" and other movies
    similarity_with_other_items = similarity_with_other_items.sort_values(ascending=False)
    print('-----------------------------------------')
    print("target item", i)
    if similarity_with_other_items.iloc[1] > 0.5 and similarity_with_other_items.iloc[1] < 0.99:
        print("************************************")
        print(similarity_with_other_items.index[1])
        print(similarity_with_other_items.iloc[1])
    else:
        print(similarity_with_other_items.iloc[1])
# Out:
# -----------------------------------------
# target item 41488
# 0.3422347218896061
# -----------------------------------------
# target item 41490
# 0.16740014806383152
# -----------------------------------------
# target item 41560
# 0.3219090969848256
# -----------------------------------------
# target item 41562
# 0.3927356678898813
# -----------------------------------------
# target item 153024
# 0.31025130988262395
# -----------------------------------------
# target item 153049
# 0.3588258857310374
# -----------------------------------------
# target item 153055
# 0.41487272696197347
# -----------------------------------------
# target item 154238
# 0.3729996122633735
# -----------------------------------------
# target item 154247
# 0.3333341005230546
# -----------------------------------------
# target item 154251
# 0.39586309842021344
# -----------------------------------------
# target item 154257
# 0.4567715900749531
# -----------------------------------------
# target item 154264
# 0.38734444508751276
# -----------------------------------------
# target item 154280
# 0.4567715900749531
# -----------------------------------------
# target item 155134
# 0.35502521958725786
# -----------------------------------------
# target item 161317
# 0.47000834510077055
# -----------------------------------------
# target item 213061
# 0.35988481451858756
# -----------------------------------------
# target item 213364
# 0.38902542126823747
# -----------------------------------------
# target item 213403
# 0.38902542126823747
# -----------------------------------------
# target item 268376
# 0.9999999999999998
# -----------------------------------------
# target item 430347
# 0.19939712654060238
# -----------------------------------------
# target item 430357
# 0.18994392833236784
# -----------------------------------------
# target item 437769
# ************************************
# 736752
# 0.5323273231802979
# -----------------------------------------
# target item 437790
# 0.3563010537169772
# -----------------------------------------
# target item 437829
# ************************************
# 437906
# 0.7117684024980387
# -----------------------------------------
# target item 437885
# ************************************
# 437829
# 0.6233288348367674
# -----------------------------------------
# target item 437906
# ************************************
# 437829
# 0.7117684024980386
# -----------------------------------------
# target item 522932
# 0.17719982661009576
# -----------------------------------------
# target item 522934
# 0.30415569511634105
# -----------------------------------------
# target item 522940
# 0.429518606835995
# -----------------------------------------
# target item 522943
# 0.3508568304515444
# -----------------------------------------
# target item 584113
# 0.36751277864942966
# -----------------------------------------
# target item 584124
# ************************************
# 584138
# 0.5077351732240617
# -----------------------------------------
# target item 584129
# 0.27483035802924866
# -----------------------------------------
# target item 584138
# ************************************
# 584124
# 0.5077351732240617
# -----------------------------------------
# target item 584149
# 0.39357892852699894
# -----------------------------------------
# target item 584214
# 0.3066234828765621
# -----------------------------------------
# target item 584223
# 0.3935789285269989
# -----------------------------------------
# target item 614007
# 0.19096484933837485
# -----------------------------------------
# target item 627094
# 0.3347102628960501
# -----------------------------------------
# target item 627473
# 0.3761978289287003
# -----------------------------------------
# target item 627591
# 0.38541551369305516
# -----------------------------------------
# target item 627655
# 0.3854155136930552
# -----------------------------------------
# target item 650712
# 0.31410947596537586
# -----------------------------------------
# target item 650726
# 0.30853013371535165
# -----------------------------------------
# target item 650738
# 0.30209001400088703
# -----------------------------------------
# target item 700798
# 0.3355692345281529
# -----------------------------------------
# target item 700853
# 0.33556923452815296
# -----------------------------------------
# target item 736743
# ************************************
# 736757
# 0.5142961292744331
# -----------------------------------------
# target item 736752
# ************************************
# 437769
# 0.5323273231802979
# -----------------------------------------
# target item 736757
# ************************************
# 736743
# 0.5142961292744331
# Wall time: 6min 32s

# %%
sub_1 = View[View['ht'] < list_1[-1]]
sub_1 = sub_1[sub_1['ht']  > list_[-1]]
sub_1 = sub_1.drop_duplicates(subset=None, keep='first', inplace=False)
sub_1
# Out:
#                                                        uid          ht  \
# 1203348  4z1Kyq8%2BklAM%2Fi282DKUKY2tOOSQdInhxvXjMUN7La...  2019-01-02
# 1203349  4z1Kyq8%2BklAM%2Fi282DKUKY2tOOSQdInhxvXjMUN7La...  2019-01-02
# 1203350  4z1Kyq8%2BklAM%2Fi282DKUKY2tOOSQdInhxvXjMUN7La...  2019-01-02
# 1203351     ASGZI2tyXaEYxtwVGAwoCzFafmdayPnzgLCHk7cfLCA%3D  2019-01-02
# 1203392   rYh169xg9FodCaPVRVT0BEV3iw5%2FqwLhtqPDQwVXxNo%3D  2019-01-02
# ...                                                    ...         ...
# 2632884   tpgMPJ54Q6GlgkAU9UoJ8jnpy8v4qFwnIFn3Ub%2Fvqg4%3D  2019-06-29
# 2632885   tpgMPJ54Q6GlgkAU9UoJ8jnpy8v4qFwnIFn3Ub%2Fvqg4%3D  2019-06-29
# 2632886  gvZQYnA8mAwLg8J7DfEwGKf0mKhtTQ%2BSt0s%2FhOmVCc...  2019-06-29
# 2632890  A3X1eK35d1yKxlMwowNJJT70Lun1J2J%2BF7HkU%2FFN9v...  2019-06-29
# 2632920  jT6Ao%2FVs9%2Ffp8%2Fns47WJR07v0NJLXiFkawaxaF%2...  2019-06-29
#
#            pr1id
# 1203348  4915333
# 1203349  5074360
# 1203350  5036875
# 1203351  3859436
# 1203392  5074753
# ...          ...
# 2632884  4808019
# 2632885  5288446
# 2632886  4956160
# 2632890  5340796
# 2632920  3664620
#
# [1115244 rows x 3 columns]

# %%
target = 437906
pair = 437829
ViewA = sub[sub['pr1id'] == target]
print(ViewA)
ViewB = sub[sub['pr1id'] == pair]
print(ViewB)
# Out:
#                                                        uid          ht   pr1id
# 1813     O%2FzMUURzDFsC%2FCPgdLpHkskJffEzDimtMEpSnccgbr...  2018-06-27  437906
# 5221        aGRpTGFDy9MeMGCDniw5r3JNbP3Q82DAbl0AUrOsQuI%3D  2018-06-27  437906
# 5421     oOcAtFZ0lUeKd%2FsITwdgPdVpSXzV5K85pZ6BpHz7F%2B...  2018-06-27  437906
# 8781     rukQI4kz8ATq91NprRp%2B%2Bq9OIarL0D9oG4xH1Skdx2...  2018-06-27  437906
# 11372    F6ebxTEfVUrC82qRg%2FVTR6hVeNmV2CGv9PzblUQ%2FcA...  2018-06-28  437906
# ...                                                    ...         ...     ...
# 1161000  tP2zzMhluZa9NirV%2F%2BKi85fA4lrOxvljA27O3Ha6CF...  2018-12-25  437906
# 1173404  Ytf3xmfaSEbE6fYeuy3sn%2F74zVGotL%2FB01E6nY0q7R...  2018-12-27  437906
# 1178405  Z0lzBCQEpFznGzMfVJgW%2BX5TpHvSOTHBZ%2FP%2By%2F...  2018-12-28  437906
# 1198223     HedMobiJkQMabD8hFChdlLzEx95LpXZ0chxynvPyYpI%3D  2018-12-31  437906
# 1203270   3lDBTCGINXptUcPxoWbV8l6MhxF0zHREFo%2Fx7MsJ7vE%3D  2018-12-31  437906
#
# [636 rows x 3 columns]
#                                                        uid          ht   pr1id
# 8317        3cAewJ9IpWPrSlU2wAxMOfQe0i8Akv8ezEv0ZujdeT8%3D  2018-06-27  437829
# 8782     rukQI4kz8ATq91NprRp%2B%2Bq9OIarL0D9oG4xH1Skdx2...  2018-06-27  437829
# 12691    eqsvjcFT%2F%2FOmEuJw9ajqrauuWtZhO%2B8hLl8g53fk...  2018-06-28  437829
# 17059     i4s%2BQCiBFXUpQHcPDJlpcqoi16TBABqkxwHJlNnhslw%3D  2018-06-29  437829
# 17449    5HvOjBbq2zKgSo18%2F%2FvC7bxlBuvIJm37NLmDAnoEh5...  2018-06-29  437829
# ...                                                    ...         ...     ...
# 1173407  Ytf3xmfaSEbE6fYeuy3sn%2F74zVGotL%2FB01E6nY0q7R...  2018-12-27  437829
# 1178408  Z0lzBCQEpFznGzMfVJgW%2BX5TpHvSOTHBZ%2FP%2By%2F...  2018-12-28  437829
# 1181711   bjVEHRiwSJ11ia%2FWiihp945NdI27IlKFqmqANpqSc5c%3D  2018-12-28  437829
# 1187048     WXjXmHNYzIi91wRhRVacULCMKEkAeM8ZqbuNEXhZUXk%3D  2018-12-29  437829
# 1201659  J%2FU8VwnQD68Ju%2F%2FYiQo1KGkXCH%2F%2BCLyoK4Re...  2018-12-31  437829
#
# [455 rows x 3 columns]

# %%
count = 0
for i in ViewA['uid']:
    if i in list(ViewB['uid']):
        count+=1
print(ViewA.shape[0])
print(ViewB.shape[0])
print(count)
print(count/ViewA.shape[0])
# Out:
# 636
# 455
# 253
# 0.3977987421383648
