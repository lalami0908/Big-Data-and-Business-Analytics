# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series
from datetime import timedelta
import time
from datetime import datetime

M_data = pd.DataFrame(pd.read_csv("/Users/kuoloading/Downloads/91ForNTUDataSet/MemberData.csv",low_memory=False))
O_data = pd.DataFrame(pd.read_csv("/Users/kuoloading/Downloads/91ForNTUDataSet/OrderData.csv",low_memory=False))
OS_data = pd.DataFrame(pd.read_csv("/Users/kuoloading/Downloads/91ForNTUDataSet/OrderSlaveData.csv",low_memory=False))
one = pd.DataFrame(pd.read_csv("/Users/kuoloading/Downloads/91ForNTUDataSet/123_new/activityPageView_2018-08-05.csv",low_memory=False))

# %%
#M_data['RegisterDateTime'] = pd.to_datetime(M_data['RegisterDateTime'].astype(str).str[0:19], format = "%Y-%m-%d %H:%M:%S") + timedelta(hours = 8 )
M_data['RegisterDateTime1'] = pd.to_datetime(M_data['RegisterDateTime'].astype(str).str[0:10], format = "%Y-%m-%d") + timedelta(hours = 8 )
OS_data['TradesDateTime1'] = pd.to_datetime(OS_data['TradesDateTime'].astype(str).str[0:19], format = "%Y-%m-%d %H:%M:%S") + timedelta(hours = 8 )
O_data['TradesDateTime1'] = pd.to_datetime(O_data['TradesDateTime'].astype(str).str[0:19], format = "%Y-%m-%d %H:%M:%S") + timedelta(hours = 8 )

# %%
indexStatus = O_data[O_data['Status'] != 'Finish'].index
indexStatus[0:20]
print(len(indexStatus))
O_data.drop(indexStatus , inplace=True)
# Out:
# 153274

# %%
sort = O_data.sort_values(by=['MemberID',"TradesGroupCode"])
sort.head(12)
# Out:
#        TradesGroupCode           TradesDateTime   ChannelType ChannelDetail  \
# 497353  TG190626A00622  2019-06-26 00:31:11.430  OfficialECom    AndroidApp
# 116350   0620180526004      2018-05-26 14:48:00           Pos             6
# 329440  TG190412U00364  2019-04-12 18:23:27.743  OfficialECom     MobileWeb
# 285397  TG190904S00363  2019-09-04 16:19:02.423  OfficialECom        iOSApp
# 294518  TG160623210407  2016-06-23 21:22:27.417  OfficialECom     MobileWeb
# 106353   0520170928001      2017-09-28 14:38:00           Pos             5
# 20193    1520170729008      2017-07-29 17:24:00           Pos           015
# 116861   0320180603019      2018-06-03 17:21:00           Pos             3
# 33360    0320180603020      2018-06-03 17:22:00           Pos             3
# 41003    0520181006028      2018-10-06 20:51:00           Pos             5
# 115029   1520180429029      2018-04-29 20:42:00           Pos            15
# ...

# %%
monetary = sort.pivot_table('TotalSalesAmount', index='MemberID',aggfunc="mean")
#age.to_csv("/Users/kuoloading/Downloads/age.csv")
monetary.head(10)
# Out:
#                                                     TotalSalesAmount
# MemberID
# %2B%2B%2FsALKlNdkh585nb%2F9geIrN84FIZZLkD8qf909...       2850.000000
# %2B%2B2Sw%2FYbIovLROVPDc%2BeVjbEdn6fTeg7niPBE%2...       1380.000000
# %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7...       3160.000000
# %2B%2B44iA8rzzl4lYN3dzParPLqAXetHBSwDFIBUBD%2B%...       1900.000000
# %2B%2B6Xs%2FwHblxbDDDYQ9osx6DMUooacHVpAJvv7KWgf...       1280.000000
# %2B%2B6ZXiIdakH%2B77WllacG4cehkRZkwBnSIX2XvAroT...       3758.000000
# %2B%2B6bo8s3RbG5E3%2FFlzz1bg7Q7D3rdOd00L7AXTUHy...       3359.000000
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...       1976.857143
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...       1726.000000
# %2B%2B9RCToUG%2F8jRD0EcLzfsQPEiC7vN64HMkzGjPxlk...       1280.000000

# %%
monetary_max = sort.pivot_table('TotalSalesAmount', index='MemberID',aggfunc="max")
#age.to_csv("/Users/kuoloading/Downloads/age.csv")
monetary_max.head(10)
# Out:
#                                                     TotalSalesAmount
# MemberID
# %2B%2B%2FsALKlNdkh585nb%2F9geIrN84FIZZLkD8qf909...              2850
# %2B%2B2Sw%2FYbIovLROVPDc%2BeVjbEdn6fTeg7niPBE%2...              1380
# %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7...              3160
# %2B%2B44iA8rzzl4lYN3dzParPLqAXetHBSwDFIBUBD%2B%...              1900
# %2B%2B6Xs%2FwHblxbDDDYQ9osx6DMUooacHVpAJvv7KWgf...              1280
# %2B%2B6ZXiIdakH%2B77WllacG4cehkRZkwBnSIX2XvAroT...              3758
# %2B%2B6bo8s3RbG5E3%2FFlzz1bg7Q7D3rdOd00L7AXTUHy...              3359
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...              3484
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...              1726
# %2B%2B9RCToUG%2F8jRD0EcLzfsQPEiC7vN64HMkzGjPxlk...              1280

# %%
frequency = sort.pivot_table('TradesGroupCode', index='MemberID',aggfunc="count")
frequency.head(10)
# Out:
#                                                     TradesGroupCode
# MemberID
# %2B%2B%2FsALKlNdkh585nb%2F9geIrN84FIZZLkD8qf909...                1
# %2B%2B2Sw%2FYbIovLROVPDc%2BeVjbEdn6fTeg7niPBE%2...                1
# %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7...                1
# %2B%2B44iA8rzzl4lYN3dzParPLqAXetHBSwDFIBUBD%2B%...                1
# %2B%2B6Xs%2FwHblxbDDDYQ9osx6DMUooacHVpAJvv7KWgf...                1
# %2B%2B6ZXiIdakH%2B77WllacG4cehkRZkwBnSIX2XvAroT...                1
# %2B%2B6bo8s3RbG5E3%2FFlzz1bg7Q7D3rdOd00L7AXTUHy...                1
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...                7
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ...                1
# %2B%2B9RCToUG%2F8jRD0EcLzfsQPEiC7vN64HMkzGjPxlk...                1

# %%
index = []
index1 = []
index2 = []
index5 = []
index6 = []
frequency['TradesGroupCode']
for i in range(len(frequency)):
    if frequency['TradesGroupCode'][i] > 1:
        index += [i]
    if frequency['TradesGroupCode'][i] > 2:
        index1 += [i]
    if frequency['TradesGroupCode'][i] > 3:
        index2 += [i]
    if frequency['TradesGroupCode'][i] > 5:
        index5 += [i]
    if frequency['TradesGroupCode'][i] > 6:
        index6 += [i]

# %%
len(index6)
# Out:
# 5381

# %%
index2
# Out:
# [7,
#  17,
#  35,
#  54,
#  77,
#  97,
#  102,
#  106,
#  121,
#  138,
#  150,
#  157,
#  170,
#  177,
#  181,
#  192,
#  194,
#  199,
#  264,
#  280,
#  287,
#  289,
#  298,
#  303,
#  308,
#  311,
#  333,
#  347,
#  353,
#  355,
#  357,
#  367,
#  391,
#  395,
#  402,
#  425,
#  427,
#  429,
#  443,
#  457,
#  465,
#  469,
#  472,
#  473,
#  496,
#  499,
#  503,
#  509,
#  510,
#  512,
#  536,
#  554,
#  563,
#  589,
#  590,
#  592,
#  594,
#  633,
#  634,
#  649,
#  656,
#  657,
#  662,
#  665,
#  670,
#  673,
#  702,
#  705,
#  714,
#  718,
#  726,
#  733,
#  739,
#  744,
#  762,
#  764,
#  766,
#  767,
#  785,
#  793,
#  795,
#  800,
#  802,
#  812,
#  814,
#  820,
#  833,
#  835,
#  840,
#  853,
#  870,
#  886,
#  892,
#  894,
#  896,
#  905,
#  911,
#  919,
#  920,
#  947,
#  950,
#  967,
#  968,
#  980,
#  997,
#  1009,
#  1019,
#  1041,
#  1042,
#  1082,
#  1083,
#  1084,
#  1104,
#  1106,
#  1119,
#  1122,
#  1137,
#  1144,
#  1156,
#  1191,
#  1209,
#  1211,
#  1215,
# ...

# %%
pd.DataFrame(index2).to_csv("/Users/kuoloading/Downloads/index2.csv")

# %%
frequency.iloc[2]
# Out:
# TradesGroupCode    1
# Name: %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7YY%3D, dtype: int64

# %%
recency = sort.pivot_table('TradesDateTime1', index='MemberID',aggfunc="max")
recency
# Out:
#                                                        TradesDateTime1
# MemberID
# %2B%2B%2FsALKlNdkh585nb%2F9geIrN84FIZZLkD8qf909... 2019-06-26 08:31:11
# %2B%2B2Sw%2FYbIovLROVPDc%2BeVjbEdn6fTeg7niPBE%2... 2018-05-26 22:48:00
# %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7... 2019-04-13 02:23:27
# %2B%2B44iA8rzzl4lYN3dzParPLqAXetHBSwDFIBUBD%2B%... 2019-09-05 00:19:02
# %2B%2B6Xs%2FwHblxbDDDYQ9osx6DMUooacHVpAJvv7KWgf... 2016-06-24 05:22:27
# ...                                                                ...
# zzuyFTH0qXj2h9ABnGbVDa5JG0S%2FHP8vz9VVJjGTbw4%3D   2016-06-05 05:11:53
# zzvTsLQAKUueMvz%2Bvx%2FYptKHZIMMEu7nSWnkOiBhtR4%3D 2019-07-19 17:59:33
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D   2019-12-21 03:37:24
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D 2019-05-14 04:36:07
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D     2018-12-27 21:21:34
#
# [181386 rows x 1 columns]

# %% [markdown]
# import time
# from datetime import datetime
# #timestamp = int(time.mktime(datetime.now().timetuple()))
# closeday = recency["TradesDateTime1"].max()
#
# #a = int(closeday.timetuple())
# timestamp = int(time.mktime(closeday.timetuple()))
#
# now = datetime.fromtimestamp(10)
# timestamp
#
# t = table["TradesDateTime1"][10]
# t1 = int(time.mktime(t.timetuple()))
#
#
# c = closeday -t
# timestamp = int(time.mktime(c.timetuple()))

# %%
table = pd.concat([recency, frequency, monetary,monetary_max],axis=1)
table
# Out:
#                                                        TradesDateTime1  \
# MemberID
# %2B%2B%2FsALKlNdkh585nb%2F9geIrN84FIZZLkD8qf909... 2019-06-26 08:31:11
# %2B%2B2Sw%2FYbIovLROVPDc%2BeVjbEdn6fTeg7niPBE%2... 2018-05-26 22:48:00
# %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7... 2019-04-13 02:23:27
# %2B%2B44iA8rzzl4lYN3dzParPLqAXetHBSwDFIBUBD%2B%... 2019-09-05 00:19:02
# %2B%2B6Xs%2FwHblxbDDDYQ9osx6DMUooacHVpAJvv7KWgf... 2016-06-24 05:22:27
# ...                                                                ...
# zzuyFTH0qXj2h9ABnGbVDa5JG0S%2FHP8vz9VVJjGTbw4%3D   2016-06-05 05:11:53
# zzvTsLQAKUueMvz%2Bvx%2FYptKHZIMMEu7nSWnkOiBhtR4%3D 2019-07-19 17:59:33
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D   2019-12-21 03:37:24
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D 2019-05-14 04:36:07
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D     2018-12-27 21:21:34
#
#                                                     TradesGroupCode  \
# MemberID
# ...

# %%
name1 = ["TradesDateTime1","TradesGroupCode","TotalSalesAmount","sum"]
table.columns = name1

# %%
table
# Out:
#                                                        TradesDateTime1  \
# MemberID
# %2B%2B%2FsALKlNdkh585nb%2F9geIrN84FIZZLkD8qf909... 2019-06-26 08:31:11
# %2B%2B2Sw%2FYbIovLROVPDc%2BeVjbEdn6fTeg7niPBE%2... 2018-05-26 22:48:00
# %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7... 2019-04-13 02:23:27
# %2B%2B44iA8rzzl4lYN3dzParPLqAXetHBSwDFIBUBD%2B%... 2019-09-05 00:19:02
# %2B%2B6Xs%2FwHblxbDDDYQ9osx6DMUooacHVpAJvv7KWgf... 2016-06-24 05:22:27
# ...                                                                ...
# zzuyFTH0qXj2h9ABnGbVDa5JG0S%2FHP8vz9VVJjGTbw4%3D   2016-06-05 05:11:53
# zzvTsLQAKUueMvz%2Bvx%2FYptKHZIMMEu7nSWnkOiBhtR4%3D 2019-07-19 17:59:33
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D   2019-12-21 03:37:24
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D 2019-05-14 04:36:07
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D     2018-12-27 21:21:34
#
#                                                     TradesGroupCode  \
# MemberID
# ...

# %%
#tabel["r"] = table["TradesDateTime1"]
closeday = recency["TradesDateTime1"].max()
temp = []
for i in range(len(table)):
    temp += [(closeday - table["TradesDateTime1"][i]).days]
x = np.array(temp)
x.max()
# Out:
# 2404

# %%
#所有Fare的算術平均數
mu = x.mean()
#標準差
std = x.std()
#標準化後之結果
z_temp= (x - mu) / std

print(z_temp)
# Out:
# [-0.79179487 -0.01192349 -0.64409195 ... -1.14037374 -0.70514249
#  -0.43533851]

# %%
m_ = table["TotalSalesAmount"]
m_z_temp = []
m_mu = m_.mean()
m_std = m_.std()
m_z_temp= (m_ - m_mu) / m_std
print(m_z_temp)
# Out:
# MemberID
# %2B%2B%2FsALKlNdkh585nb%2F9geIrN84FIZZLkD8qf909HvCU%3D      1.337501
# %2B%2B2Sw%2FYbIovLROVPDc%2BeVjbEdn6fTeg7niPBE%2FeJJKo%3D   -0.575033
# %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7YY%3D        1.740825
# %2B%2B44iA8rzzl4lYN3dzParPLqAXetHBSwDFIBUBD%2B%2Bt4%3D      0.101510
# %2B%2B6Xs%2FwHblxbDDDYQ9osx6DMUooacHVpAJvv7KWgf3o%3D       -0.705138
#                                                               ...
# zzuyFTH0qXj2h9ABnGbVDa5JG0S%2FHP8vz9VVJjGTbw4%3D           -0.705138
# zzvTsLQAKUueMvz%2Bvx%2FYptKHZIMMEu7nSWnkOiBhtR4%3D         -0.705138
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D           -0.011247
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D         -0.640085
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D              3.217835
# Name: TotalSalesAmount, Length: 181386, dtype: float64

# %%
table["TradesGroupCode"].describe()
# Out:
# count    181386.000000
# mean          1.924779
# std           2.375565
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max         342.000000
# Name: TradesGroupCode, dtype: float64

# %%
f_ = table["TradesGroupCode"]

f_mu = f_.mean()
f_std = f_.std()
f_z_temp= (f_ - f_mu) / f_std
print(f_z_temp)
# Out:
# MemberID
# %2B%2B%2FsALKlNdkh585nb%2F9geIrN84FIZZLkD8qf909HvCU%3D     -0.389288
# %2B%2B2Sw%2FYbIovLROVPDc%2BeVjbEdn6fTeg7niPBE%2FeJJKo%3D   -0.389288
# %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7YY%3D       -0.389288
# %2B%2B44iA8rzzl4lYN3dzParPLqAXetHBSwDFIBUBD%2B%2Bt4%3D     -0.389288
# %2B%2B6Xs%2FwHblxbDDDYQ9osx6DMUooacHVpAJvv7KWgf3o%3D       -0.389288
#                                                               ...
# zzuyFTH0qXj2h9ABnGbVDa5JG0S%2FHP8vz9VVJjGTbw4%3D           -0.389288
# zzvTsLQAKUueMvz%2Bvx%2FYptKHZIMMEu7nSWnkOiBhtR4%3D         -0.389288
# zzw%2Bk3PFtOtuOIu62cuXNkLNLUFDlgmXZj2XeMTwl2g%3D            0.452617
# zzw9O6yOUvVbxgrvUGCnmjjacARx%2FbQ%2F12aZDz27TbE%3D          0.031664
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D              2.557379
# Name: TradesGroupCode, Length: 181386, dtype: float64

# %%
table["r_by_days"] = x
table["r_normal"] = z_temp
table["f_normal"] = f_z_temp
table["m_normal"] = m_z_temp

# %%
name = ["r","f","m","m_sum","r_by_days","r_normal","f_normal","m_normal"]
table.columns = name

# %%
table.head(20)
# Out:
#                                                                      r   f  \
# MemberID
# %2B%2B%2FsALKlNdkh585nb%2F9geIrN84FIZZLkD8qf909... 2019-06-26 08:31:11   1
# %2B%2B2Sw%2FYbIovLROVPDc%2BeVjbEdn6fTeg7niPBE%2... 2018-05-26 22:48:00   1
# %2B%2B3XVjBiQPLoAXWc7gK%2BTdvTH4J4AmgkeFlB3mmN7... 2019-04-13 02:23:27   1
# %2B%2B44iA8rzzl4lYN3dzParPLqAXetHBSwDFIBUBD%2B%... 2019-09-05 00:19:02   1
# %2B%2B6Xs%2FwHblxbDDDYQ9osx6DMUooacHVpAJvv7KWgf... 2016-06-24 05:22:27   1
# %2B%2B6ZXiIdakH%2B77WllacG4cehkRZkwBnSIX2XvAroT... 2017-09-28 22:38:00   1
# %2B%2B6bo8s3RbG5E3%2FFlzz1bg7Q7D3rdOd00L7AXTUHy... 2017-07-30 01:24:00   1
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC... 2019-01-08 22:00:34   7
# %2B%2B8lPULC%2BdY%2F3MWf4kbymzr1cx%2B3Eaktr2fvQ... 2018-12-15 02:31:16   1
# %2B%2B9RCToUG%2F8jRD0EcLzfsQPEiC7vN64HMkzGjPxlk... 2018-03-30 02:03:37   1
# %2B%2BAxIR%2FMP7E3PHys4cxjjgCzWuwinageEcPXGH8SX... 2016-10-16 18:26:00   1
# ...

# %%
table.to_csv("/Users/kuoloading/Downloads/rfm_new.csv")

# %%
table2 =table

# %%
a = pd.DataFrame()
#k = 0
for i in index5:
  #  k+=1
    #str_1 =  str(i)
    #a= pd.concat(a,table2.iloc[[i],:])
    a = pd.concat([a, table2.iloc[[i],:]], axis=0)
    ##if k ==10:
      #  break
    #table2 = table2.drop([table.index[i]])
   # print (str_1)
#table2.iloc[[1],:]

# %%
a
# Out:
#                                                                      r   f  \
# MemberID
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC... 2019-01-08 22:00:34   7
# %2B%2BP3hhogUcwlFXNq%2FN%2F%2BF9UFR%2BXcIHzrhS8... 2020-02-24 18:20:00  11
# %2B%2FrFyVWMWO4cpgJls1OgjyoxEc35KE2HA0HB0gKP33g%3D 2020-01-02 21:32:26  15
# %2B2L3qeMLfbpnoT09K00DdiGfrvTEiK6grWnkvFlAiw0%3D   2020-02-10 04:54:21  12
# %2B3ewi8VLqI8BqfOC%2F4jmUyOwhunaQjenxx0QtPTKNM8%3D 2020-02-04 17:19:59  11
# ...                                                                ...  ..
# zxjVQqQsHkkJevOxObiJ3NKxSKtTPnuWyUA5NyHqH38%3D     2019-01-15 03:22:55   6
# zyBezm9UGFfvCGL0MFL0HyS0OvAmMyVqHuX%2BA%2B4ZNHI%3D 2019-06-05 00:20:00   6
# zzA89nWMnfG4gOIB73ZFqWkd3z8N5ujHW99wAPCJ7V4%3D     2020-04-07 11:57:35   6
# zzDxaBctzlencSpoNRT%2BEejnHvnJylFnYbE1m42XT6c%3D   2019-09-22 19:25:44   6
# zzwvJvTcevm90Q6BkxJqud94QGdwcvDOrWT88F1cTM4%3D     2018-12-27 21:21:34   8
#
# ...

# %%
a.to_csv("/Users/kuoloading/Downloads/a5.csv")

# %%
a.head()
# Out:
#                                                                      r   f  \
# MemberID
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC... 2019-01-08 22:00:34   7
# %2B%2BP3hhogUcwlFXNq%2FN%2F%2BF9UFR%2BXcIHzrhS8... 2020-02-24 18:20:00  11
# %2B%2FrFyVWMWO4cpgJls1OgjyoxEc35KE2HA0HB0gKP33g%3D 2020-01-02 21:32:26  15
# %2B2L3qeMLfbpnoT09K00DdiGfrvTEiK6grWnkvFlAiw0%3D   2020-02-10 04:54:21  12
# %2B3ewi8VLqI8BqfOC%2F4jmUyOwhunaQjenxx0QtPTKNM8%3D 2020-02-04 17:19:59  11
#
#                                                               m  m_sum  \
# MemberID
# %2B%2B8NpYVoqyjmc8mROiPMlX%2F2J8JlOghaysSF3qbYC...  1976.857143   3484
# %2B%2BP3hhogUcwlFXNq%2FN%2F%2BF9UFR%2BXcIHzrhS8...  2136.363636   4060
# %2B%2FrFyVWMWO4cpgJls1OgjyoxEc35KE2HA0HB0gKP33g%3D  1701.466667   3287
# %2B2L3qeMLfbpnoT09K00DdiGfrvTEiK6grWnkvFlAiw0%3D    1599.166667   4040
# %2B3ewi8VLqI8BqfOC%2F4jmUyOwhunaQjenxx0QtPTKNM8%3D  1901.727273   3382
#
# ...
